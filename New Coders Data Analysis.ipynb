# %%
# workon dataanalysis - my virtual environment
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('2016-FCC-New-Coders-Survey-Data.csv')
# Out:
# /Users/Monica/.virtualenvs/dataanalysis/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(3)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 0                NaN             NaN       ...                     NaN
# 1                NaN             NaN       ...                     NaN
# 2                NaN             NaN       ...                     NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
#
#                               SchoolDegree  SchoolMajor  StudentDebtOwe
# 0           some college credit, no degree          NaN         20000.0
# 1           some college credit, no degree          NaN             NaN
# 2  high school diploma or equivalent (GED)          NaN             NaN
#
# [3 rows x 113 columns]

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Who does this data represent? Age? Gender breakdown?

# %%
print("According to this survey the average developer is", round(df['Age'].mean()), "years old.")
# Out:
# According to this survey the average developer is 29.0 years old.

# %%
ageHis = df['Age'].hist()# .hist(bins=#)
ageHis.set_title('Distribution of Age Amongst Respondents to the Survey')
ageHis.set_xlabel('Age(years)')
ageHis.set_ylabel('# of Respondents')
plt.savefig('agehis.png')

# %%
df['Gender'].value_counts()
# Out:
# male           10766
# female          2840
# genderqueer       66
# agender           38
# trans             36
# Name: Gender, dtype: int64

# %%
genderBar = df['Gender'].value_counts().plot(kind="bar", color = ['#624ea7', 'g', 'yellow', 'k', 'maroon'])
genderBar.set_title('Distribution of Gender Amongst Respondents to the Survey')
genderBar.set_xlabel('Gender')
genderBar.set_ylabel('# of Respondents')
plt.savefig('genderbar.png')

# %%
genderPie = df['Gender'].value_counts().plot(kind="pie",  colors = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple'],  labeldistance=1.2)
genderPie.set_title('Distribution of Gender Amongst Respondents to the Survey')
genderPie.set_xlabel('Gender')
genderPie.set_ylabel('# of Respondents')
plt.savefig('genderpie.png')

# %%
df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
df.columns.value_counts() #view all columns -- regular columns command  truncates the values
# Out:
# Part1StartTime                 1
# BootcampMonthsAgo              1
# EmploymentStatus               1
# PodcastDeveloperTea            1
# ResourceHackerRank             1
# ResourceDevTips                1
# SchoolDegree                   1
# BootcampLoanYesNo              1
# JobApplyWhen                   1
# PodcastProgrammingThrowDown    1
# AttendedBootcamp               1
# ResourceStackOverflow          1
# CodeEventWorkshop              1
# JobRoleInterestOther           1
# BootcampFullJobAfter           1
# ResourceSoloLearn              1
# ChildrenNumber                 1
# ResourceLynda                  1
# PodcastNone                    1
# CodeEventNone                  1
# ResourceUdemy                  1
# HasServedInMilitary            1
# ResourceBooks                  1
# Gender                         1
# ExpectedEarning                1
# ResourceTreehouse              1
# ResourceKhanAcademy            1
# PodcastOther                   1
# ResourceOther                  1
# Part1EndTime                   1
#                               ..
# CountryLive                    1
# IsEthnicMinority               1
# BootcampFinish                 1
# ResourceReddit                 1
# ResourceCoursera               1
# ResourceEdX                    1
# ResourceUdacity                1
# ID.x                           1
# ResourceGoogle                 1
# PodcastSEDaily                 1
# ResourcePluralSight            1
# IsSoftwareDev                  1
# PodcastJSJabber                1
# PodcastTalkPython              1
# CodeEventCoffee                1
# PodcastCodeNewbie              1
# ResourceCodeWars               1
# MaritalStatus                  1
# ResourceOdinProj               1
# HoursLearning                  1
# ResourceYouTube                1
# ResourceCodecademy             1
# ID.y                           1
# HasStudentDebt                 1
# IsUnderEmployed                1
# CodeEventRailsBridge           1
# PodcastJsAir                   1
# CodeEventBootcamp              1
# NetworkID                      1
# PodcastDotNetRocks             1
# dtype: int64

# %% [markdown]
# Aside from university tuition, about how much money have you spent on learning to code so far (in US dollars)?

# %%
df['MoneyForLearning'].value_counts()
# Out:
# 0.0        6587
# 100.0      1071
# 200.0       756
# 500.0       716
# 50.0        564
# 1000.0      518
# 300.0       444
# 20.0        221
# 150.0       217
# 2000.0      217
# 400.0       198
# 30.0        193
# 5000.0      165
# 250.0       152
# 3000.0      137
# 1500.0      126
# 10.0        118
# 10000.0     114
# 60.0        112
# 40.0        105
# 600.0       100
# 4000.0       89
# 25.0         74
# 15000.0      70
# 20000.0      65
# 2500.0       61
# 12000.0      60
# 700.0        58
# 800.0        57
# 1200.0       52
#            ...
# 199.0         1
# 190.0         1
# 185.0         1
# 1900.0        1
# 12050.0       1
# 174.0         1
# 2009.0        1
# 84000.0       1
# 2100.0        1
# 145.0         1
# 834.0         1
# 1650.0        1
# 236.0         1
# 239.0         1
# 320.0         1
# 17550.0       1
# 345.0         1
# 341.0         1
# 1206.0        1
# 1221.0        1
# 325.0         1
# 1250.0        1
# 1537.0        1
# 299.0         1
# 288.0         1
# 280.0         1
# 275.0         1
# 1296.0        1
# 17800.0       1
# 93000.0       1
# Name: MoneyForLearning, dtype: int64

# %%
df['MoneyForLearning'].value_counts().sort_values().head(4)
# Out:
# 93000.0    1
# 8650.0     1
# 8600.0     1
# 13.0       1
# Name: MoneyForLearning, dtype: int64

# %%
moneyScatter = df.plot(kind='scatter', x='Age', y='MoneyForLearning', alpha=0.2, xlim=(8, 85),ylim = (0, 200000))
moneyScatter.set_title('Distribution of Money Spent Amongst Respondents to the Survey by Age')
moneyScatter.set_xlabel('Age')
moneyScatter.set_ylabel('Amount Spent ($USD)')
plt.savefig('moneyscatter.png')

# %%
moneyBar = df['MoneyForLearning'].hist(bins=20, range=(0,93000)) # trying to figure out data because the range is from 0 to $93,000
moneyBar.set_title('Distribution of Money Spent A color = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple']mongst Respondents to the Survey by Age')
moneyBar.set_xlabel('Age')
moneyBar.set_ylabel('Amount Spent')
plt.savefig('moneybar.png')
# Out:
#   File "<ipython-input-280-916e1d9b4bc9>", line 3
#     moneyBar.set_xlabel('Age')
#            ^
# SyntaxError: invalid syntax

# %%
expectedEarningsGender = df.groupby('Gender')['ExpectedEarning'].mean().plot(kind="bar", color = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple'])
expectedEarningsGender.set_title('Money Expected to Earn Amongst Respondents to the Survey by Gender')
expectedEarningsGender.set_xlabel('Gender')
expectedEarningsGender.set_ylabel('Amount Expected ($ USD)')
plt.savefig('expectedEarningsGender.png')

# %%
moneySpentExpectedScatter = df.plot(kind='scatter', x='MoneyForLearning', y='ExpectedEarning', ylim=(0, 220000), xlim=(0,93000), alpha=0.2)
moneySpentExpectedScatter.set_title('Money Spent for Learning versus Expected Earning ($USD)')
moneySpentExpectedScatter.set_xlabel('Money for Learning ($USD)')
moneySpentExpectedScatter.set_ylabel('Expected Earning ($USD)')
plt.savefig('spentvsexpectedscatter.png')

# %%
bootcamps =df[df['BootcampRecommend'].notnull()]

# %%
bootcamps['BootcampRecommend']

# %%
bootcamps.head()

# %%
#convert 1s and 0s into yes and nos
#save this response into a new row in the bootcamps df
bootcamps['YesNoBoot']= bootcamps["BootcampRecommend"].apply(str).replace("1.0", "Yes!").apply(str).replace("0.0", "No.")

#look at the new yes/no value column that we created that is associated with whether or not an individual recommends a bootcamp
recBootcamp = bootcamps['YesNoBoot'].value_counts().plot(kind="pie",  colors=['#cc0099', '#800060'])


# recBootcamp.setLineColor(0xffffff)

recBootcamp.set_title('Would you recommend attending a bootcamp?')
recBootcamp.set_ylabel('')
plt.savefig('recommendbootcampyesorno.png')

# %%
#look at the new yes/no value column that we created that is associated with whether or not an individual recommends a bootcamp
ethnicMinority = df['IsEthnicMinority'].value_counts().plot(kind="pie",  colors=['#cc0099', '#800060'], labels=['ethnic minority', 'not ethnic minority'])

ethnicMinority.set_title('Respondents that identified as ethnic minorities')
ethnicMinority.set_ylabel('')
plt.savefig('ethnicminority.png')

# recBootcamp.setLineColor(0xffffff)

#recBootcamp.set_title('Would you recommend attending a bootcamp?')
#recBootcamp.set_ylabel('')
#plt.savefig('recommendbootcampyesorno.png')

# %%
bootcamps.head()

# %%
df.groupby('CountryLive')['ExpectedEarning'].mean()
# Out:
# CountryLive
# Afghanistan                  40000.000000
# Albania                      42320.000000
# Algeria                      17000.000000
# Andorra                     100000.000000
# Angola                                NaN
# Argentina                    35331.944444
# Armenia                               NaN
# Australia                    56720.720721
# Austria                      45454.545455
# Azerbaijan                    9600.000000
# Bahamas                               NaN
# Bangladesh                   35400.000000
# Barbados                     18000.000000
# Belarus                      33560.000000
# Belgium                      38130.434783
# Belize                                NaN
# Benin                                 NaN
# Bermuda                               NaN
# Bolivia                      85000.000000
# Bosnia & Herzegovina         25622.222222
# Botswana                              NaN
# Brazil                       38954.848485
# Brunei                                NaN
# Bulgaria                     38700.000000
# Cambodia                      6000.000000
# Cameroon                     36000.000000
# Canada                       53572.856459
# Channel Islands                       NaN
# Chile                        29566.666667
# China                        37281.050000
#                                 ...
# Slovakia                     25100.000000
# Slovenia                     57000.000000
# South Africa                 43507.200000
# Spain                        37343.061224
# Sri Lanka                    50000.000000
# Sudan                        24000.000000
# Swaziland                             NaN
# Sweden                       45500.000000
# Switzerland                  59000.000000
# Syria                         6000.000000
# Taiwan                       47635.533333
# Tanzania                     50000.000000
# Thailand                     70857.142857
# Tokelau                               NaN
# Trinidad & Tobago            80000.000000
# Tunisia                      43250.000000
# Turkey                       37850.000000
# Uganda                       10000.000000
# Ukraine                      30331.818182
# United Arab Emirates         45200.000000
# United Kingdom               37846.364444
# United States of America     63455.397805
# Uruguay                      11000.000000
# Uzbekistan                   80000.000000
# Venezuela                    37076.923077
# Vietnam                      33669.230769
# Virgin Islands (British)              NaN
# Virgin Islands (USA)         50000.000000
# Zambia                                NaN
# Zimbabwe                              NaN
# Name: ExpectedEarning, dtype: float64

# %%
USMinority = df[df['CountryLive'] == 'United States of America']
USMinority.groupby('IsEthnicMinority')['ExpectedEarning'].mean()
# Out:
# IsEthnicMinority
# 0.0    62359.345992
# 1.0    65266.819541
# Name: ExpectedEarning, dtype: float64

# %%
MinorityExpectedEarnings = USMinority.groupby('IsEthnicMinority')['ExpectedEarning'].mean().plot(kind="bar",  color = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple'])
MinorityExpectedEarnings.set_xticklabels(('Not Ethnic Minority', 'Ethnic Minority'))
MinorityExpectedEarnings .set_title('Money Expected to Earn Amongst Respondents to the Survey ')
MinorityExpectedEarnings .set_xlabel('')
MinorityExpectedEarnings .set_ylabel('Amount Expected ($ USD)')

# %%
df['JobRoleInterest'].value_counts()
# Out:
# Full-Stack Web Developer            2571
#   Front-End Web Developer           1379
# Back-End Web Developer               704
#   Data Scientist / Data Engineer     646
#   Mobile Developer                   414
#   User Experience Designer           275
#   DevOps / SysAdmin                  219
#   Product Manager                    191
#   Quality Assurance Engineer         104
# Name: JobRoleInterest, dtype: int64

# %%
df['JobRoleInterest'].value_counts().plot(kind="bar",  color = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple']).set_ylabel('Amount of Respondents')
plt.savefig('jobRoleInterest.png')

# %% [markdown]
# # want to explore this question more!
# Which types of in-person coding events have you attended?
#
# Question Type:
# Type: Categorical/Boolean
# Options:
# coffee-and-codes (CodeEventCoffee)
# hackathons (CodeEventHackathons)
# conferences (CodeEventConference)
# NodeSchool (CodeEventNodeSchool)
# RailsBridge (CodeEventRailsBridge)
# Startup Weekend (CodeEventStartUpWknd)
# Women Who Code (CodeEventWomenCode)
# Girl Develop It (CodeEventGirlDev)
# None (CodeEventNone)
# Other (CodeEventOther)
# Note: This question allowed multiple options. Thus, each option has its own column named as the option itself. Each value of a cell in these columns were the option name itself. The "Other" category allowed for user input for their answer. The "Other" column is next to the other columns, given the raw data. Will need to normalize this text if present.

# %%
hoursLearning = df['HoursLearning'].hist(bins=50)
hoursLearning.set_xlabel('Hours Spent Coding (Weekly)')
hoursLearning.set_ylabel('Amount of Respondents')
plt.savefig('hoursLearning.png')

# %%
moneyScatter = df.plot(kind='scatter', x='MonthsProgramming', y='HoursLearning', alpha=0.2, xlim=(0, 750),ylim = (0, 110))
#moneyScatter.set_title('Distribution of Money Spent Amongst Respondents to the Survey by Age')
moneyScatter.set_xlabel('Months Programming')
moneyScatter.set_ylabel('Hours Spent Learning Each Week')
plt.savefig('studyingovertime.png')

# %%
df.groupby('CountryLive')['HasHighSpdInternet']

# %%
df['HasHighSpdInternet'].value_counts().plot(kind="pie",  colors = ['#624ea7', '#599ad3', '#f9a65a', '#9e66ab', 'purple'],  labeldistance=1.2, labels=['Has Internet','Does Not Have Internet']).set_ylabel('')
plt.savefig('internet.png')
